# %% [markdown]
# W3A1

# %%
n = int(input())
donvi = n % 10
hangnghin = (n // 1000) % 10
print("đơn vị là:", donvi)
print("hàng nghìn là:", hangnghin)
# Out:
# đơn vị là: 5
# hàng nghìn là: 2

# %% [markdown]
# CÁC PHÉP TOÁN TRÊN BIT
#
# and (&): and bit (1&1 =1 còn lại bằng  0 hết)
# or (|):or bit (0|0=0, còn lại bằng 1 hết)
# xor(^): xor bit (khác nhau thì bằng 1, giống nhau thì bằng 0)
# not(!): lật bit (1=>0, 0=>1)
#
# 12345
# 987=7*10^0 + 8*10^1 + 9*10^2
# Hệ Thập Phân (hệ10) dùng 10 chữ số từ 0.....9
# Hệ Nhị Phân (hệ2) dùng 2 chữ số 0,1
# 19 =1*10^1 + 9*10^0
# 19 =1*2^4 + 0*2^3 + 0*2^2 + 1*2^1 +1*2^0

# %% [markdown]
# W3A2

# %%
a,b = map(int, input().split())
a,b = b,a
print(a,b)
# Out:
# 5 4

# %% [markdown]
# W3A3 Kiểm tra 1 số có phải lũy thừa của 2 không
# Gợi ý: với lũy thừa của 2, n & (n-1) == 0
#  VD: 16 = 00010000 (1*2^4 số 1 ở vị trí thứ 5 từ bên phải sang trái)
#      15 = 0000...1

# %%
n = int(input())
if n > 0 and (n & (n - 1)) == 0:
    print("n là lũy thừa của 2")
else:
    print("n không phải là lũy thừa của 2")
# Out:
# n là lũy thừa của 2

# %% [markdown]
# W3A4
# LÀM TRÒN LÊN
# VD 2/3 = 0.66666
# Lấy đến 3 chữ số => nhân 10^3 =>0.667
# Cho số thực n và một số nguyên k, in ra số thực n lấy đến k chữ số phần thập phân
# 0.666000 nếu k=3 => 0.666

# %%
# Nhập hai số m và n trên cùng một dòng, cách nhau bởi dấu cách
m, n = map(int, input().split())

# Toán tử // sẽ tự động chia và làm tròn xuống
ket_qua = m // n

# In kết quả
print(ket_qua)
# Out:
# 0

# %% [markdown]
# W3A5

# %%
m, n = map(int, input().split())

# Cứ chia lấy phần nguyên trước
ket_qua = m // n

# Nếu chia có dư (tức là phần dư khác 0), ta cộng thêm 1
if m % n != 0:
    ket_qua += 1

print(ket_qua)
# Out:
# 1

# %% [markdown]
# W3A6

# %%
x = int(input().strip())

if x % 2 == 0:
    print("Even")
else:
    print("Odd")

# %% [markdown]
# W3A7

# %%
# Nhập trên 2 dòng
a = int(input().strip())
b = int(input().strip())

# Điều kiện: CẢ a VÀ b đều phải nhỏ hơn 0
if a < 0 and b < 0:
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A8

# %%
a = input().strip()
b = input().strip()

# So sánh độ dài
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# W3A9

# %%
a,b,c = map(int, input().split())
if a+b>c and a+c>b and b+c>a:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %% [markdown]
# W3A10

# %%
n,m,k,p = map(int, input().split())
_max= n
if m > _max:
    _max=m
if k>_max:
    _max=k
if p>_max:
    _max=p
print("số lớn nhất là:", _max)
# Out:
# số lớn nhất là: 6

# %% [markdown]
# W3A11

# %%
a,b,c = map(int, input().split())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("Tam giác đều")
    elif a==b or a==c or b==c:
        print("Tam giác cân")
    else:
        print("Tam giác thường")
else:
    print("Không phải tam giác")
# Out:
# Tam giác thường

# %% [markdown]
# W3A12

# %%
n = int(input())
if (n%4==0 and n%100!=0) or (n%400==0):
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# W3A13

# %%
t = int(input())
s = 0

if t <= 50:
    s = t * 1500
elif t <= 100:
    # Xóa dấu ngoặc thừa ở cuối dòng này
    s = (50 * 1500) + ((t - 50) * 2000) 
else:
    s = (50 * 1500) + (50 * 2000) + ((t - 100) * 3000)

print(s)
# Out:
# 60000

# %% [markdown]
# W2A14

# %%
a = float(input().strip())
b = float(input().strip())

if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    n = -b / a
    print(f"{n:.2f}")
# Out:
# 3.00

# %% [markdown]
# W3A15

# %%
diem = float(input().strip())

if diem >= 8.0:
    print("Giỏi")
elif diem >= 6.5:
    print("Khá")
elif diem >= 5.0:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Khá

# %% [markdown]
# W3A16

# %%
n=float(input().strip())
a =int(n//1)
b =int(-(-n//1))
if n>=0:
    c=int(n+0.5)
else:
    c=int(n-0.5)
print(b,a,c)
# Out:
# -7 -8 -8

# %% [markdown]
# W3A17

# %%
a,b,c,d=map(int, input().split())
q=b/a
if b/a==c/b==d/c:
    print("Yes")
else:
    print("No")
# Out:
# No
